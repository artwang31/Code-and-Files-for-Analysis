# %%
import pandas as pd

# %%
# %cd "/Users/artemaswang/Desktop/" #one way to set working directory

# %%
nba = pd.read_excel('/Users/artemaswang/Desktop/NBA Player Stats.xlsx',
                    skiprows = [0], # skips the first row
                    sheet_name = None) # None reads in all sheets
# type(nba['2018-2019']) -- sheet name becoems the key,

# %%
nba['2018-2019']
# Out:
#      RANK      FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     NaN     Marc Gasol  Tor    C  34.37  24  30.6
# 1     NaN    Danny Green  Tor  G-F  31.98  24  28.5
# 2     NaN    Serge Ibaka  Tor  F-C  29.74  24  20.8
# 3     NaN  Kawhi Leonard  Tor    F  27.96  24  39.1
# 4     NaN     Kyle Lowry  Tor    G  33.22  24  37.5
# ..    ...            ...  ...  ...    ...  ..   ...
# 207   NaN  Chris Boucher  Tor    F  26.42   2   2.1
# 208   NaN        TJ Leaf  Ind    F  22.12   1   9.8
# 209   NaN      Jon Leuer  Det    F  30.09   1   4.9
# 210   NaN   Kyle O'Quinn  Ind    C  29.22   1   1.6
# 211   NaN  Edmond Sumner  Ind    G  23.45   1   1.6
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 63.8
# 1                                                 59.4
# 2                                                 43.4
# 3                                                 81.6
# ...

# %%
#reading in data
nba2 = pd.ExcelFile('/Users/artemaswang/Desktop/NBA Player Stats.xlsx') 
#checking sheet names
nba_sheets2 = nba2.sheet_names

# %%
# creating a dictionary to store all sheets
nba_df2 = {} 
# for every sheet in excel file, sheet_name turns into string format in dictionary named nba
for sheet in nba2.sheet_names:
    nba_df2[f'{sheet}']= pd.read_excel(nba2, sheet_name = sheet)

# %%
nba_df2['2018-2019'] # same as above
# Out:
#     2018-2019 NBA Player Stats     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         RANK      FULL NAME       TEAM        POS
# 1                          NaN     Marc Gasol        Tor          C
# 2                          NaN    Danny Green        Tor        G-F
# 3                          NaN    Serge Ibaka        Tor        F-C
# 4                          NaN  Kawhi Leonard        Tor          F
# ..                         ...            ...        ...        ...
# 208                        NaN  Chris Boucher        Tor          F
# 209                        NaN        TJ Leaf        Ind          F
# 210                        NaN      Jon Leuer        Det          F
# 211                        NaN   Kyle O'Quinn        Ind          C
# 212                        NaN  Edmond Sumner        Ind          G
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0          AGE         GP        MPG
# 1        34.37         24       30.6
# ...
